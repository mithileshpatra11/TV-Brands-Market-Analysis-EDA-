# %% [markdown]
# <a href="https://colab.research.google.com/github/mithileshpatra11/TV-Brands-Market-Analysis-EDA-/blob/main/TV_Brands_Market_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/sample_data/TV_Final.csv')

# %%
df.head()
# Out:
#      Brand     Resolution  Size   Selling Price  Original Price  \
# 0  TOSHIBA   Ultra HD LED     55          37999           54990
# 1     TCL   QLED Ultra HD     55          52999          129990
# 2  realme          HD LED     32          13999           17999
# 3      Mi          HD LED     32          14999           19999
# 4  realme          HD LED     32          12999           21999
#
#   Operating System  Rating
# 0            VIDAA     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3

# %%
df.shape
# Out:
# (912, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             912 non-null    object
#  1   Resolution        912 non-null    object
#  2   Size              912 non-null    int64
#  3   Selling Price     912 non-null    int64
#  4   Original Price    912 non-null    int64
#  5   Operating System  901 non-null    object
#  6   Rating            692 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 50.0+ KB

# %%
df['Brand'].unique()
# Out:
# array(['TOSHIBA', 'TCL ', 'realme ', 'Mi ', 'OnePlus', 'Hisense', 'LG ',
#        'MarQ by Flipkart', 'iFFALCON by TCL', 'Coocaa ', 'SAMSUNG',
#        'Infinix', 'Vu', 'Nokia ', 'Thomson', 'SONY ', 'KODAK ',
#        'MOTOROLA', 'PHILIPS', 'Acer', 'Blaupunkt', 'Adsun', 'T-Series',
#        'Panasonic', 'Micromax', 'Sansui ', 'Croma ', 'Candes ', 'Dyanora',
#        'Haier ', 'Onida', 'RGL ', 'Lloyd ', 'LumX ', 'Onix ', 'IMPEX ',
#        'BPL ', 'CloudWalker', 'Oxygen ', 'Power Guard', 'Akai ', 'VG ',
#        'Sun King', 'Compaq ', 'HUIDI ', 'Intex ', 'DETEL ', 'JVC',
#        'G-TEN ', 'Skyworth', 'Maser ', 'Sanyo ', 'MURPHY ', 'Samsung',
#        'Dektron', 'Sharp ', 'KRISONS', 'Weston ', 'AISEN  '], dtype=object)

# %%
df['Brand'] = df['Brand'].replace('Samsung', 'SAMSUNG')

# %%
df['Brand'].unique()
# Out:
# array(['TOSHIBA', 'TCL ', 'realme ', 'Mi ', 'OnePlus', 'Hisense', 'LG ',
#        'MarQ by Flipkart', 'iFFALCON by TCL', 'Coocaa ', 'SAMSUNG',
#        'Infinix', 'Vu', 'Nokia ', 'Thomson', 'SONY ', 'KODAK ',
#        'MOTOROLA', 'PHILIPS', 'Acer', 'Blaupunkt', 'Adsun', 'T-Series',
#        'Panasonic', 'Micromax', 'Sansui ', 'Croma ', 'Candes ', 'Dyanora',
#        'Haier ', 'Onida', 'RGL ', 'Lloyd ', 'LumX ', 'Onix ', 'IMPEX ',
#        'BPL ', 'CloudWalker', 'Oxygen ', 'Power Guard', 'Akai ', 'VG ',
#        'Sun King', 'Compaq ', 'HUIDI ', 'Intex ', 'DETEL ', 'JVC',
#        'G-TEN ', 'Skyworth', 'Maser ', 'Sanyo ', 'MURPHY ', 'Dektron',
#        'Sharp ', 'KRISONS', 'Weston ', 'AISEN  '], dtype=object)

# %%
df['Brand'].nunique()
# Out:
# 58

# %%
df['Resolution'].unique()
# Out:
# array(['Ultra HD LED', 'QLED Ultra HD', 'HD LED', 'Full HD LED',
#        'HD Plasma'], dtype=object)

# %%
df['Operating System'].unique()
# Out:
# array(['VIDAA', 'Android', 'Linux', nan, 'Tizen', 'WebOS', 'HomeOS',
#        'FireTV OS'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Brand                 0
# Resolution            0
# Size                  0
# Selling Price         0
# Original Price        0
# Operating System     11
# Rating              220
# dtype: int64

# %% [markdown]
# count of products by Resolution

# %%
df.head()
# Out:
#      Brand     Resolution  Size   Selling Price  Original Price  \
# 0  TOSHIBA   Ultra HD LED     55          37999           54990
# 1     TCL   QLED Ultra HD     55          52999          129990
# 2  realme          HD LED     32          13999           17999
# 3      Mi          HD LED     32          14999           19999
# 4  realme          HD LED     32          12999           21999
#
#   Operating System  Rating
# 0            VIDAA     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3

# %%
ans = df['Brand'].groupby(df['Resolution']).count().sort_values(ascending=False)
ans
# Out:
# Resolution
# Ultra HD LED     399
# HD LED           229
# Full HD LED      220
# QLED Ultra HD     60
# HD Plasma          4
# Name: Brand, dtype: int64

# %%
ans.keys()
# Out:
# Index(['Ultra HD LED', 'HD LED', 'Full HD LED', 'QLED Ultra HD', 'HD Plasma'], dtype='object', name='Resolution')

# %% [markdown]
# CONCLUSION: LED's tv are more in demand.

# %% [markdown]
# Device Type distribution

# %%
x = ['Ultra HD LED', 'QLED Ultra HD', 'HD LED', 'Full HD LED','HD Plasma']
y = [399,229,220,60,4]
plt.figure(figsize=(15,10));
plt.barh(x, y)

 
for index, value in enumerate(y):
    plt.text(value, index,
             str(value))
 
plt.show()

# %% [markdown]
# Which are the top 5 brands for TV?

# %%
df.head()
# Out:
#      Brand     Resolution  Size   Selling Price  Original Price  \
# 0  TOSHIBA   Ultra HD LED     55          37999           54990
# 1     TCL   QLED Ultra HD     55          52999          129990
# 2  realme          HD LED     32          13999           17999
# 3      Mi          HD LED     32          14999           19999
# 4  realme          HD LED     32          12999           21999
#
#   Operating System  Rating
# 0            VIDAA     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3

# %%
df['Brand'].groupby(df['Brand']).count().sort_values(ascending=False).head()
# Out:
# Brand
# SAMSUNG      146
# LG           122
# SONY          62
# TCL           44
# Panasonic     30
# Name: Brand, dtype: int64

# %% [markdown]
# Brands and Resolution

# %%
plt.figure(figsize=(15,10));
sns.countplot(y="Brand", hue="Resolution", data=df, palette='flare',order=df["Brand"].value_counts().iloc[:5].index);

# %% [markdown]
# Are TVs with higher ratings more expensive or do expensive TVs from well-known brands have higher ratings indicating premium quality?

# %%
df.head()
# Out:
#      Brand     Resolution  Size   Selling Price  Original Price  \
# 0  TOSHIBA   Ultra HD LED     55          37999           54990
# 1     TCL   QLED Ultra HD     55          52999          129990
# 2  realme          HD LED     32          13999           17999
# 3      Mi          HD LED     32          14999           19999
# 4  realme          HD LED     32          12999           21999
#
#   Operating System  Rating
# 0            VIDAA     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3

# %%
round(df.groupby('Brand')['Rating'].mean().sort_values(ascending=False), 1)
# Out:
# Brand
# SONY                4.5
# OnePlus             4.4
# Hisense             4.4
# Haier               4.4
# Vu                  4.4
# TOSHIBA             4.4
# MOTOROLA            4.3
# Mi                  4.3
# Compaq              4.3
# Onida               4.3
# Thomson             4.3
# Onix                4.3
# Dektron             4.3
# KODAK               4.3
# iFFALCON by TCL     4.3
# LG                  4.3
# realme              4.3
# MarQ by Flipkart    4.3
# Nokia               4.3
# SAMSUNG             4.3
# Coocaa              4.2
# Blaupunkt           4.2
# Weston              4.2
# TCL                 4.2
# Sanyo               4.2
# Infinix             4.2
# Intex               4.2
# Panasonic           4.2
# IMPEX               4.1
# Croma               4.1
# Sansui              4.1
# Micromax            4.1
# PHILIPS             4.1
# HUIDI               4.1
# CloudWalker         4.1
# Candes              4.1
# Lloyd               4.1
# JVC                 4.0
# DETEL               4.0
# LumX                4.0
# Acer                3.9
# RGL                 3.9
# G-TEN               3.8
# T-Series            3.8
# Maser               3.8
# Adsun               3.8
# BPL                 3.7
# Dyanora             3.7
# Sharp               3.4
# AISEN               3.3
# MURPHY              3.1
# Skyworth            3.0
# Akai                NaN
# KRISONS             NaN
# Oxygen              NaN
# Power Guard         NaN
# Sun King            NaN
# VG                  NaN
# Name: Rating, dtype: float64

# %%
df['Brand'].unique()
# Out:
# array(['TOSHIBA', 'TCL ', 'realme ', 'Mi ', 'OnePlus', 'Hisense', 'LG ',
#        'MarQ by Flipkart', 'iFFALCON by TCL', 'Coocaa ', 'SAMSUNG',
#        'Infinix', 'Vu', 'Nokia ', 'Thomson', 'SONY ', 'KODAK ',
#        'MOTOROLA', 'PHILIPS', 'Acer', 'Blaupunkt', 'Adsun', 'T-Series',
#        'Panasonic', 'Micromax', 'Sansui ', 'Croma ', 'Candes ', 'Dyanora',
#        'Haier ', 'Onida', 'RGL ', 'Lloyd ', 'LumX ', 'Onix ', 'IMPEX ',
#        'BPL ', 'CloudWalker', 'Oxygen ', 'Power Guard', 'Akai ', 'VG ',
#        'Sun King', 'Compaq ', 'HUIDI ', 'Intex ', 'DETEL ', 'JVC',
#        'G-TEN ', 'Skyworth', 'Maser ', 'Sanyo ', 'MURPHY ', 'Dektron',
#        'Sharp ', 'KRISONS', 'Weston ', 'AISEN  '], dtype=object)

# %%
# Rating vs Selling Price
# filter by Known Brands

list1 = ["SONY","OnePlus","Haier","Vu","TOSHIBA","MOTOROLA","Mi","Compaq","Onida","Thomson",
        "KODAK","LG","realme","SAMSUNG","Nokia","Panasonic","Sansui","Micromax","PHILIPS","Samsung","JVC"]

list2 = ["Hisense","Thomson","Onix","KODAK","Dektron","iFFALCON by TCL","MarQ by Flipkart","Nokia","Coocaa","Blaupunkt","Weston","TCL",
        "Infinix","Sanyo","Intex","IMPEX","Croma","HUIDI","CloudWalker","Lloyd", 
        "Candes","Detel","LumX"]

series1 = df["Brand"].isin(list1)
series2 = df["Brand"].isin(list2)
df_f1= df[series1]
df_f2= df[series2]
fig, axs = plt.subplots(ncols=2,figsize=(20,5))
ax1 = sns.stripplot(x='Rating', y='Selling Price', data=df_f1, hue='Brand', palette=sns.color_palette(), ax=axs[0])
ax2 = sns.stripplot(x='Rating', y='Selling Price', data=df_f2, hue='Brand', palette=sns.color_palette(), ax=axs[1])

# %% [markdown]
# The first plot on the left side shows well-known Brands with expensive TVs and their ratings while the second one on the right shows new and lesser-known brands with their selling prices and ratings. From the second plot, even the lesser known brands have a higher rating >4.0. So, it is possible that ratings are not highly influnced by brand name alone.

# %% [markdown]
# **Average selling price by Resolution**

# %%
df.groupby(df['Resolution']).mean()
# Out:
#                    Size   Selling Price  Original Price    Rating
# Resolution
# Full HD LED    43.436364   52720.022727    62550.368182  4.243094
# HD LED         31.004367   15471.310044    21712.240175  4.101111
# HD Plasma      48.000000   57245.000000    57245.000000  3.650000
# QLED Ultra HD  57.466667  125417.450000   180293.083333  4.460000
# Ultra HD LED   54.145363   78294.954887   112735.954887  4.287075

# %%
plt.figure(figsize=(15,10));
sns.barplot(x= df['Resolution'], y=df['Selling Price'], palette=sns.color_palette());

# %% [markdown]
# **Average selling price by Brand**

# %%
df.head()
# Out:
#      Brand     Resolution  Size   Selling Price  Original Price  \
# 0  TOSHIBA   Ultra HD LED     55          37999           54990
# 1     TCL   QLED Ultra HD     55          52999          129990
# 2  realme          HD LED     32          13999           17999
# 3      Mi          HD LED     32          14999           19999
# 4  realme          HD LED     32          12999           21999
#
#   Operating System  Rating
# 0            VIDAA     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3

# %%
df.groupby(by='Brand').mean().sort_values(by= 'Selling Price', ascending=False).apply(np.ceil)
# Out:
#                   Size   Selling Price  Original Price  Rating
# Brand
# Sharp              47.0       149672.0        156657.0     4.0
# SAMSUNG            51.0       107035.0        131638.0     5.0
# LG                 51.0        96915.0        135398.0     5.0
# Hisense            53.0        89796.0        100790.0     5.0
# SONY               50.0        89343.0        130394.0     5.0
# TCL                51.0        55799.0         99361.0     5.0
# iFFALCON by TCL    55.0        54235.0         99991.0     5.0
# Panasonic          47.0        53494.0         75295.0     5.0
# Akai               55.0        52003.0         82190.0     NaN
# OnePlus            50.0        47376.0         54200.0     5.0
# Vu                 51.0        46650.0         66152.0     5.0
# Compaq             49.0        45999.0         83198.0     5.0
# Sanyo              52.0        45499.0         70990.0     5.0
# Weston             46.0        43390.0         43390.0     5.0
# Oxygen             53.0        40327.0         73657.0     NaN
# Nokia              50.0        38863.0         55727.0     5.0
# TOSHIBA            50.0        38853.0         55070.0     5.0
# MOTOROLA           49.0        38399.0         54826.0     5.0
# Sansui             45.0        37672.0         44851.0     5.0
# Haier              45.0        36617.0         54977.0     5.0
# AISEN              43.0        35463.0         41190.0     4.0
# BPL                45.0        34618.0         49000.0     4.0
# Onix               42.0        34217.0         39110.0     5.0
# Lloyd              41.0        34162.0         52752.0     5.0
# PHILIPS            45.0        34114.0         63991.0     5.0
# JVC                46.0        32497.0         54000.0     5.0
# CloudWalker        46.0        32332.0         45492.0     5.0
# Acer               46.0        31665.0         43435.0     4.0
# Mi                 45.0        30788.0         37578.0     5.0
# Power Guard        41.0        30510.0         41900.0     NaN
# Onida              39.0        29708.0         40359.0     5.0
# IMPEX              39.0        28820.0         38383.0     5.0
# Intex              43.0        27341.0         38544.0     5.0
# Micromax           36.0        26870.0         33518.0     5.0
# Thomson            44.0        25249.0         33971.0     5.0
# Sun King           32.0        24999.0         49998.0     NaN
# LumX               38.0        24859.0         35249.0     4.0
# Coocaa             46.0        24443.0         54436.0     5.0
# realme             40.0        24428.0         33142.0     5.0
# Blaupunkt          44.0        23713.0         38833.0     5.0
# KODAK              43.0        23666.0         30530.0     5.0
# Croma              36.0        22366.0         31667.0     5.0
# VG                 39.0        19493.0         32125.0     NaN
# HUIDI              39.0        18166.0         26366.0     5.0
# DETEL              40.0        18111.0         45000.0     5.0
# MarQ by Flipkart   36.0        17749.0         27624.0     5.0
# T-Series           36.0        17180.0         22718.0     4.0
# Infinix            39.0        17166.0         23330.0     5.0
# G-TEN              42.0        16919.0         39010.0     4.0
# Dyanora            37.0        15516.0         23999.0     4.0
# Adsun              39.0        15221.0         27714.0     4.0
# Candes             33.0        13416.0         24924.0     5.0
# MURPHY             30.0        12818.0         15745.0     4.0
# RGL                29.0        11107.0         16643.0     4.0
# Skyworth           24.0         8659.0         12490.0     3.0
# Maser              24.0         7499.0          7999.0     4.0
# Dektron            22.0         6724.0         10249.0     5.0
# KRISONS            19.0         5866.0          7666.0     NaN

# %% [markdown]
# **Average selling price by Operating System**

# %%
df.head()
# Out:
#      Brand     Resolution  Size   Selling Price  Original Price  \
# 0  TOSHIBA   Ultra HD LED     55          37999           54990
# 1     TCL   QLED Ultra HD     55          52999          129990
# 2  realme          HD LED     32          13999           17999
# 3      Mi          HD LED     32          14999           19999
# 4  realme          HD LED     32          12999           21999
#
#   Operating System  Rating
# 0            VIDAA     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3

# %%
df.groupby(by='Operating System')['Selling Price'].mean().sort_values(ascending=False).apply(np.ceil)
# Out:
# Operating System
# Tizen        107460.0
# WebOS        106342.0
# Linux         50359.0
# Android       40680.0
# VIDAA         38853.0
# FireTV OS     30490.0
# HomeOS        18232.0
# Name: Selling Price, dtype: float64

# %%
plt.figure(figsize=(15,10));
sns.barplot(x=df['Operating System'], y=df['Selling Price'], palette=sns.color_palette());
plt.title('Operating System vs Selling Price');

# %% [markdown]
# From the above chart, it is clear the Television sets with Tizen and WebOS are most expensive while HomeOS Television sets are the most affordable ones.

# %% [markdown]
# **Brand and Discount Percentage on Original Price**

# %%
df['Discount_percentage']=((df['Original Price']-df['Selling Price'])/df['Original Price'])*100

# %%
df.head()
# Out:
#      Brand     Resolution  Size   Selling Price  Original Price  \
# 0  TOSHIBA   Ultra HD LED     55          37999           54990
# 1     TCL   QLED Ultra HD     55          52999          129990
# 2  realme          HD LED     32          13999           17999
# 3      Mi          HD LED     32          14999           19999
# 4  realme          HD LED     32          12999           21999
#
#   Operating System  Rating  Discount_percentage
# 0            VIDAA     4.3            30.898345
# 1          Android     4.4            59.228402
# 2          Android     4.3            22.223457
# 3          Android     4.4            25.001250
# 4          Android     4.3            40.910950

# %%
df[['Brand', 'Discount_percentage']].sort_values(by='Discount_percentage', ascending=False)
# Out:
#                Brand  Discount_percentage
# 882             TCL             71.060353
# 25           Coocaa             70.264936
# 880             TCL             69.154577
# 449             TCL             68.419917
# 58   iFFALCON by TCL            66.352930
# ..               ...                  ...
# 684          SAMSUNG             0.000000
# 685          SAMSUNG             0.000000
# 686              LG              0.000000
# 687          SAMSUNG             0.000000
# 911            SONY              0.000000
#
# [912 rows x 2 columns]

# %% [markdown]
# Conclusion:
#
# There is a clear demand for different types of televisions looking at the number of products offered by 58 unique brands in the market
# Brands like SAMSUNG, LG, TOSHIBA seems to be quite popular but there are a number of upcoming brands with competitive products in the market.
# SAMSUNG has the highest number of products i.e. televisions
# There is no clear correlation between selling price and higher ratings for televisions
# Average Selling Price by Brand - Sharp, SAMSUNG and LG are the most expensive brands.
